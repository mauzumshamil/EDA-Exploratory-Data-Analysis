# %% [markdown]
#  PROJECT DONE BY MAUZUM SHAMIL

# %% [markdown]
# # Data prepocessing and data cleaning

# %% [markdown]
# # clearing missing value

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('beer-servings.csv')
df
# Out:
#      Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0             0  Afghanistan            0.0              0.0            0.0
# 1             1      Albania           89.0            132.0           54.0
# 2             2      Algeria           25.0              0.0           14.0
# 3             3      Andorra          245.0            138.0          312.0
# 4             4       Angola          217.0             57.0           45.0
# ..          ...          ...            ...              ...            ...
# 188         188    Venezuela            NaN            100.0            3.0
# 189         189      Vietnam          111.0              2.0            1.0
# 190         190        Yemen            6.0              0.0            0.0
# 191         191       Zambia           32.0             19.0            4.0
# 192         192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# ...

# %%
df.head()
# Out:
#    Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0           0  Afghanistan            0.0              0.0            0.0
# 1           1      Albania           89.0            132.0           54.0
# 2           2      Algeria           25.0              0.0           14.0
# 3           3      Andorra          245.0            138.0          312.0
# 4           4       Angola          217.0             57.0           45.0
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    193 non-null    int64
#  1   country                       193 non-null    object
#  2   beer_servings                 185 non-null    float64
#  3   spirit_servings               185 non-null    float64
#  4   wine_servings                 187 non-null    float64
#  5   total_litres_of_pure_alcohol  192 non-null    float64
#  6   continent                     193 non-null    object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 10.7+ KB

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.head(5)
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0              0.0            0.0
# 1      Albania           89.0            132.0           54.0
# 2      Algeria           25.0              0.0           14.0
# 3      Andorra          245.0            138.0          312.0
# 4       Angola          217.0             57.0           45.0
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 185 non-null    float64
#  2   spirit_servings               185 non-null    float64
#  3   wine_servings                 187 non-null    float64
#  4   total_litres_of_pure_alcohol  192 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(4), object(2)
# memory usage: 9.2+ KB

# %%
df.dtypes
# Out:
# country                          object
# beer_servings                   float64
# spirit_servings                 float64
# wine_servings                   float64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
df.isna().sum()
# Out:
# country                         0
# beer_servings                   8
# spirit_servings                 8
# wine_servings                   6
# total_litres_of_pure_alcohol    1
# continent                       0
# dtype: int64

# %%
null_df=df.select_dtypes(include=['float'])
null_df
# Out:
#      beer_servings  spirit_servings  wine_servings  \
# 0              0.0              0.0            0.0
# 1             89.0            132.0           54.0
# 2             25.0              0.0           14.0
# 3            245.0            138.0          312.0
# 4            217.0             57.0           45.0
# ..             ...              ...            ...
# 188            NaN            100.0            3.0
# 189          111.0              2.0            1.0
# 190            6.0              0.0            0.0
# 191           32.0             19.0            4.0
# 192           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol
# 0                             0.0
# 1                             4.9
# 2                             0.7
# 3                            12.4
# 4                             5.9
# ..                            ...
# 188                           7.7
# 189                           2.0
# ...

# %%
df.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
null_df.hist(figsize=(20,6))
# Out:
# array([[<Axes: title={'center': 'beer_servings'}>,
#         <Axes: title={'center': 'spirit_servings'}>],
#        [<Axes: title={'center': 'wine_servings'}>,
#         <Axes: title={'center': 'total_litres_of_pure_alcohol'}>]],
#       dtype=object)

# %% [markdown]
# its have skewness so its median for allcolumns

# %%
for i in ['beer_servings', 'spirit_servings', 'wine_servings','total_litres_of_pure_alcohol']:
  df[i]=df[i].fillna(df[i].median())
df[i]
# Out:
# 0       0.0
# 1       4.9
# 2       0.7
# 3      12.4
# 4       5.9
#        ...
# 188     7.7
# 189     2.0
# 190     0.1
# 191     2.5
# 192     4.7
# Name: total_litres_of_pure_alcohol, Length: 193, dtype: float64

# %%
df.isnull().sum()
# Out:
# country                         0
# beer_servings                   0
# spirit_servings                 0
# wine_servings                   0
# total_litres_of_pure_alcohol    0
# continent                       0
# dtype: int64

# %% [markdown]
# # outlier detection and removing

# %%
df.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
plt.subplots(2,2,figsize=(20,6))
plt.subplot(2,2,1)
plt.boxplot(df['beer_servings'])
plt.subplot(2,2,2)
plt.boxplot(df['spirit_servings'])
plt.title('spirit')
plt.subplot(2,2,3)
plt.boxplot(df['wine_servings'])
plt.title('wine')
plt.subplot(2,2,4)
plt.boxplot(df['total_litres_of_pure_alcohol'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7937ffc0c520>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7937ffc0ca60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7937ffc0c280>],
#  'medians': [<matplotlib.lines.Line2D at 0x7937ffc0cfd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7937ffc0d270>],
#  'means': []}

# %%
Q1 = np.percentile(df['spirit_servings'],25,interpolation='midpoint')
Q2 = np.percentile(df['spirit_servings'],50,interpolation='midpoint')
Q3 = np.percentile(df['spirit_servings'],75,interpolation='midpoint')

print(Q1)
print(Q2)
print(Q3)
# Out:
# 5.0
# 60.0
# 128.0

# %%
IQR=Q3-Q1
IQR
# Out:
# 123.0

# %%
upperlimit=Q3+1.5*IQR
lowerlimit=Q1-1.5*IQR

print(lowerlimit)
print(upperlimit)
# Out:
# -179.5
# 312.5

# %%
outlier=[]
for x in df['spirit_servings']:
  if ((x>upperlimit) or (x<lowerlimit)):
    outlier.append(x)
outlier
# Out:
# [373.0, 438.0, 326.0, 326.0, 315.0]

# %%
out = df['spirit_servings']>upperlimit
print(out)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Name: spirit_servings, Length: 193, dtype: bool

# %%
df.loc[out]
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 15              Belarus          142.0            373.0           42.0
# 68              Grenada          199.0            438.0           28.0
# 73                Haiti            1.0            326.0            1.0
# 141  Russian Federation          247.0            326.0           73.0
# 144           St. Lucia          171.0            315.0           71.0
#
#      total_litres_of_pure_alcohol      continent
# 15                           14.4         Europe
# 68                           11.9  North America
# 73                            5.9  North America
# 141                          11.5           Asia
# 144                          10.1  North America

# %%
df.loc[out].index
# Out:
# Int64Index([15, 68, 73, 141, 144], dtype='int64')

# %%
df.drop([15, 68, 73, 141, 144],inplace=True)

# %%
df.reset_index()
# Out:
#      index      country  beer_servings  spirit_servings  wine_servings  \
# 0        0  Afghanistan            0.0              0.0            0.0
# 1        1      Albania           89.0            132.0           54.0
# 2        2      Algeria           25.0              0.0           14.0
# 3        3      Andorra          245.0            138.0          312.0
# 4        4       Angola          217.0             57.0           45.0
# ..     ...          ...            ...              ...            ...
# 183    188    Venezuela           76.0            100.0            3.0
# 184    189      Vietnam          111.0              2.0            1.0
# 185    190        Yemen            6.0              0.0            0.0
# 186    191       Zambia           32.0             19.0            4.0
# 187    192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# ...

# %%
plt.boxplot(df['spirit_servings'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7937ffad42b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7937ffad47f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7937ffca7fd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7937ffad4c10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7937ffad4eb0>],
#  'means': []}

# %%
df.head(3)
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0              0.0            0.0
# 1      Albania           89.0            132.0           54.0
# 2      Algeria           25.0              0.0           14.0
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa

# %%
Q1 = np.percentile(df['wine_servings'],25,interpolation='midpoint')
Q2 = np.percentile(df['wine_servings'],50,interpolation='midpoint')
Q3 = np.percentile(df['wine_servings'],75,interpolation='midpoint')

print(Q1)
print(Q2)
print(Q3)
# Out:
# 1.0
# 9.0
# 57.5

# %%
IQR = Q3-Q1
IQR
# Out:
# 56.5

# %%
upperlimit=Q3+1.5*IQR
lowerlimit=Q1-1.5*IQR

print(lowerlimit)
print(upperlimit)
# Out:
# -83.75
# 142.25

# %%
outlier=[]
for y in df['spirit_servings']:
  if ((y>upperlimit) or (y<lowerlimit)):
    outlier.append(y)
outlier
# Out:
# [179.0,
#  176.0,
#  173.0,
#  173.0,
#  145.0,
#  252.0,
#  192.0,
#  254.0,
#  154.0,
#  170.0,
#  286.0,
#  147.0,
#  194.0,
#  151.0,
#  302.0,
#  215.0,
#  202.0,
#  246.0,
#  216.0,
#  152.0,
#  244.0,
#  189.0,
#  200.0,
#  160.0,
#  186.0,
#  215.0,
#  226.0,
#  205.0,
#  221.0,
#  293.0,
#  157.0,
#  178.0,
#  258.0,
#  156.0,
#  237.0,
#  158.0]

# %%
out2 = df['wine_servings']>upperlimit

# %%
df.loc[out2].index
# Out:
# Int64Index([  3,   6,   8,   9,  16,  35,  42,  48,  55,  61,  64,  65,  67,
#              75,  81,  83,  99, 120, 121, 136, 140, 156, 165, 166, 182, 185],
#            dtype='int64')

# %%
df.drop([  3,   6,   8,   9,  16,  35,  42,  48,  55,  61,  64,  65,  67,
         75,  81,  83,  99, 120, 121, 136, 140, 156, 165, 166, 182, 185],inplace=True)

# %%
df.head(6)
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan            0.0              0.0            0.0
# 1            Albania           89.0            132.0           54.0
# 2            Algeria           25.0              0.0           14.0
# 4             Angola          217.0             57.0           45.0
# 5  Antigua & Barbuda          102.0            128.0           45.0
# 7            Armenia           21.0            179.0           11.0
#
#    total_litres_of_pure_alcohol      continent
# 0                           0.0           Asia
# 1                           4.9         Europe
# 2                           0.7         Africa
# 4                           5.9         Africa
# 5                           4.9  North America
# 7                           3.8         Europe

# %%
df.reset_index()
# Out:
#      index            country  beer_servings  spirit_servings  wine_servings  \
# 0        0        Afghanistan            0.0              0.0            0.0
# 1        1            Albania           89.0            132.0           54.0
# 2        2            Algeria           25.0              0.0           14.0
# 3        4             Angola          217.0             57.0           45.0
# 4        5  Antigua & Barbuda          102.0            128.0           45.0
# ..     ...                ...            ...              ...            ...
# 157    188          Venezuela           76.0            100.0            3.0
# 158    189            Vietnam          111.0              2.0            1.0
# 159    190              Yemen            6.0              0.0            0.0
# 160    191             Zambia           32.0             19.0            4.0
# 161    192           Zimbabwe           64.0             18.0            4.0
#
# ...

# %% [markdown]
# # Encoding
# machine learning model does not take categorical values so encoding required
#
#
# *   one hot encoding
# *   label encoding

# %% [markdown]
# one hot encoding

# %%
df.shape
# Out:
# (162, 6)

# %%
df.dtypes
# Out:
# country                          object
# beer_servings                   float64
# spirit_servings                 float64
# wine_servings                   float64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
df.head()
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan            0.0              0.0            0.0
# 1            Albania           89.0            132.0           54.0
# 2            Algeria           25.0              0.0           14.0
# 4             Angola          217.0             57.0           45.0
# 5  Antigua & Barbuda          102.0            128.0           45.0
#
#    total_litres_of_pure_alcohol      continent
# 0                           0.0           Asia
# 1                           4.9         Europe
# 2                           0.7         Africa
# 4                           5.9         Africa
# 5                           4.9  North America

# %%
df1=pd.get_dummies(df)

# %%
df1.shape
# Out:
# (162, 172)

# %%
df.country.nunique()
# Out:
# 162

# %%
df.continent.nunique()
# Out:
# 6

# %%
df2=df.drop('country',axis=1)

# %%
df2=pd.get_dummies(df2)
df2.head(10)
# Out:
#     beer_servings  spirit_servings  wine_servings  \
# 0             0.0              0.0            0.0
# 1            89.0            132.0           54.0
# 2            25.0              0.0           14.0
# 4           217.0             57.0           45.0
# 5           102.0            128.0           45.0
# 7            21.0            179.0           11.0
# 10           21.0             46.0            5.0
# 11          122.0            176.0           51.0
# 12           42.0             63.0            7.0
# 13           76.0             60.0            9.0
#
#     total_litres_of_pure_alcohol  continent_Africa  continent_Asia  \
# 0                           0.00                 0               1
# 1                           4.90                 0               0
# 2                           0.70                 1               0
# 4                           5.90                 1               0
# 5                           4.90                 0               0
# ...

# %% [markdown]
# label encoding

# %%
df.head()
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan            0.0              0.0            0.0
# 1            Albania           89.0            132.0           54.0
# 2            Algeria           25.0              0.0           14.0
# 4             Angola          217.0             57.0           45.0
# 5  Antigua & Barbuda          102.0            128.0           45.0
#
#    total_litres_of_pure_alcohol      continent
# 0                           0.0           Asia
# 1                           4.9         Europe
# 2                           0.7         Africa
# 4                           5.9         Africa
# 5                           4.9  North America

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df.head()
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan            0.0              0.0            0.0
# 1            Albania           89.0            132.0           54.0
# 2            Algeria           25.0              0.0           14.0
# 4             Angola          217.0             57.0           45.0
# 5  Antigua & Barbuda          102.0            128.0           45.0
#
#    total_litres_of_pure_alcohol      continent
# 0                           0.0           Asia
# 1                           4.9         Europe
# 2                           0.7         Africa
# 4                           5.9         Africa
# 5                           4.9  North America

# %%
df['continent']=le.fit_transform(df['continent'])

# %%
df.head()
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan            0.0              0.0            0.0
# 1            Albania           89.0            132.0           54.0
# 2            Algeria           25.0              0.0           14.0
# 4             Angola          217.0             57.0           45.0
# 5  Antigua & Barbuda          102.0            128.0           45.0
#
#    total_litres_of_pure_alcohol  continent
# 0                           0.0          1
# 1                           4.9          2
# 2                           0.7          0
# 4                           5.9          0
# 5                           4.9          3

# %% [markdown]
# # scaling
# scaling only done for features ie values used for predicting,scaling not done on target columns
#
# *   minmax scaling
# *   standard scaling

# %% [markdown]
# minmax scaling

# %%
x = df.drop('total_litres_of_pure_alcohol',axis=1)
y = df['total_litres_of_pure_alcohol']
z = df['continent']

# %%
x.head()
# Out:
#              country  beer_servings  spirit_servings  wine_servings  continent
# 0        Afghanistan            0.0              0.0            0.0          1
# 1            Albania           89.0            132.0           54.0          2
# 2            Algeria           25.0              0.0           14.0          0
# 4             Angola          217.0             57.0           45.0          0
# 5  Antigua & Barbuda          102.0            128.0           45.0          3

# %%
x = x.drop('country',axis=1)

# %% [markdown]
# scaling is not done on encoded columns,so removing continent columns

# %%
x = x.drop('continent',axis=1)

# %%
x.head(10)
# Out:
#     beer_servings  spirit_servings  wine_servings
# 0             0.0              0.0            0.0
# 1            89.0            132.0           54.0
# 2            25.0              0.0           14.0
# 4           217.0             57.0           45.0
# 5           102.0            128.0           45.0
# 7            21.0            179.0           11.0
# 10           21.0             46.0            5.0
# 11          122.0            176.0           51.0
# 12           42.0             63.0            7.0
# 13           76.0             60.0            9.0

# %%
x.drop('level_0',axis=1,inplace=True)

# %%
x.drop('index',axis=1,inplace=True)

# %%
x.head(10)
# Out:
#    beer_servings  spirit_servings  wine_servings
# 0            0.0              0.0            0.0
# 1           89.0            132.0           54.0
# 2           25.0              0.0           14.0
# 3          217.0             57.0           45.0
# 4          102.0            128.0           45.0
# 5           21.0            179.0           11.0
# 6           21.0             46.0            5.0
# 7          122.0            176.0           51.0
# 8           42.0             63.0            7.0
# 9           76.0             60.0            9.0

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax = MinMaxScaler(feature_range=(0,1))

# %%
X1=minmax.fit_transform(x)

# %%
type(X1)
# Out:
# numpy.ndarray

# %%
X1 = pd.DataFrame(X1,columns=['beer_servings', 'spirit_servings', 'wine_servings'])

# %%
X1.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings
# count     162.000000       162.000000     162.000000
# mean        0.230299         0.239208       0.153722
# std         0.244585         0.262603       0.248742
# min         0.000000         0.000000       0.000000
# 25%         0.045878         0.009934       0.007463
# 50%         0.144947         0.142384       0.052239
# 75%         0.337766         0.399834       0.139925
# max         1.000000         1.000000       1.000000

# %%
X2=pd.concat([X1,z,y],axis=1)

# %%
X2.head()
# Out:
#    beer_servings  spirit_servings  wine_servings  continent  \
# 0       0.000000         0.000000       0.000000        1.0
# 1       0.236702         0.437086       0.402985        2.0
# 2       0.066489         0.000000       0.104478        0.0
# 3       0.577128         0.188742       0.335821        NaN
# 4       0.271277         0.423841       0.335821        0.0
#
#    total_litres_of_pure_alcohol
# 0                           0.0
# 1                           4.9
# 2                           0.7
# 3                           NaN
# 4                           5.9

# %% [markdown]
#  standard scaling

# %%
df.reset_index(inplace=True)

# %%
df.head(10)
# Out:
#    index            country  beer_servings  spirit_servings  wine_servings  \
# 0      0        Afghanistan            0.0              0.0            0.0
# 1      1            Albania           89.0            132.0           54.0
# 2      2            Algeria           25.0              0.0           14.0
# 3      4             Angola          217.0             57.0           45.0
# 4      5  Antigua & Barbuda          102.0            128.0           45.0
# 5      7            Armenia           21.0            179.0           11.0
# 6     10         Azerbaijan           21.0             46.0            5.0
# 7     11            Bahamas          122.0            176.0           51.0
# 8     12            Bahrain           42.0             63.0            7.0
# 9     13         Bangladesh           76.0             60.0            9.0
#
#    total_litres_of_pure_alcohol  continent
# 0                          0.00          1
# 1                          4.90          2
# ...

# %%
df.drop('index',axis=1,inplace=True)

# %%
df.head(10)
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan            0.0              0.0            0.0
# 1            Albania           89.0            132.0           54.0
# 2            Algeria           25.0              0.0           14.0
# 3             Angola          217.0             57.0           45.0
# 4  Antigua & Barbuda          102.0            128.0           45.0
# 5            Armenia           21.0            179.0           11.0
# 6         Azerbaijan           21.0             46.0            5.0
# 7            Bahamas          122.0            176.0           51.0
# 8            Bahrain           42.0             63.0            7.0
# 9         Bangladesh           76.0             60.0            9.0
#
#    total_litres_of_pure_alcohol  continent
# 0                          0.00          1
# 1                          4.90          2
# 2                          0.70          0
# 3                          5.90          0
# ...

# %%
x=df.drop('total_litres_of_pure_alcohol',axis=1)
y=df['total_litres_of_pure_alcohol']
z=df['continent']

# %%
x.head(5)
# Out:
#              country  beer_servings  spirit_servings  wine_servings  continent
# 0        Afghanistan            0.0              0.0            0.0          1
# 1            Albania           89.0            132.0           54.0          2
# 2            Algeria           25.0              0.0           14.0          0
# 3             Angola          217.0             57.0           45.0          0
# 4  Antigua & Barbuda          102.0            128.0           45.0          3

# %%
x= x.drop('country',axis=1)

# %%
x= x.drop('continent',axis=1)

# %%
x.head()
# Out:
#    beer_servings  spirit_servings  wine_servings
# 0            0.0              0.0            0.0
# 1           89.0            132.0           54.0
# 2           25.0              0.0           14.0
# 3          217.0             57.0           45.0
# 4          102.0            128.0           45.0

# %%
from sklearn.preprocessing import StandardScaler

# %%
stdsclr = StandardScaler()

# %%
z1 = stdsclr.fit_transform(x)

# %%
type(z1)
# Out:
# numpy.ndarray

# %%
z1 = pd.DataFrame(z1,columns=['beer_servings', 'spirit_servings', 'wine_servings'])

# %%
z1
# Out:
#      beer_servings  spirit_servings  wine_servings
# 0        -0.944513        -0.913736      -0.619914
# 1         0.026259         0.755864       1.005200
# 2        -0.671824        -0.913736      -0.198588
# 3         1.422425        -0.192772       0.734348
# 4         0.168057         0.705270       0.734348
# ..             ...              ...            ...
# 157      -0.115539         0.351113      -0.529630
# 158       0.266225        -0.888439      -0.589819
# 159      -0.879068        -0.913736      -0.619914
# 160      -0.595471        -0.673415      -0.499535
# 161      -0.246430        -0.686063      -0.499535
#
# [162 rows x 3 columns]

# %%
z4=pd.concat([z1,y,z],axis=1)

# %%
z4
# Out:
#      beer_servings  spirit_servings  wine_servings  \
# 0        -0.944513        -0.913736      -0.619914
# 1         0.026259         0.755864       1.005200
# 2        -0.671824        -0.913736      -0.198588
# 3         1.422425        -0.192772       0.734348
# 4         0.168057         0.705270       0.734348
# ..             ...              ...            ...
# 157      -0.115539         0.351113      -0.529630
# 158       0.266225        -0.888439      -0.589819
# 159      -0.879068        -0.913736      -0.619914
# 160      -0.595471        -0.673415      -0.499535
# 161      -0.246430        -0.686063      -0.499535
#
#      total_litres_of_pure_alcohol  continent
# 0                             0.0          1
# 1                             4.9          2
# 2                             0.7          0
# 3                             5.9          0
# 4                             4.9          3
# ..                            ...        ...
# ...
