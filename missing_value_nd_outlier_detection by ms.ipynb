# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("beer-servings.csv")
df
# Out:
#      Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0             0  Afghanistan            0.0              0.0            0.0
# 1             1      Albania           89.0            132.0           54.0
# 2             2      Algeria           25.0              0.0           14.0
# 3             3      Andorra          245.0            138.0          312.0
# 4             4       Angola          217.0             57.0           45.0
# ..          ...          ...            ...              ...            ...
# 188         188    Venezuela            NaN            100.0            3.0
# 189         189      Vietnam          111.0              2.0            1.0
# 190         190        Yemen            6.0              0.0            0.0
# 191         191       Zambia           32.0             19.0            4.0
# 192         192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# ...

# %%
df.head()
# Out:
#    Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0           0  Afghanistan            0.0              0.0            0.0
# 1           1      Albania           89.0            132.0           54.0
# 2           2      Algeria           25.0              0.0           14.0
# 3           3      Andorra          245.0            138.0          312.0
# 4           4       Angola          217.0             57.0           45.0
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'beer_servings', 'spirit_servings',
#        'wine_servings', 'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    193 non-null    int64
#  1   country                       193 non-null    object
#  2   beer_servings                 185 non-null    float64
#  3   spirit_servings               185 non-null    float64
#  4   wine_servings                 187 non-null    float64
#  5   total_litres_of_pure_alcohol  192 non-null    float64
#  6   continent                     193 non-null    object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 10.7+ KB

# %%
df.dtypes
# Out:
# Unnamed: 0                        int64
# country                          object
# beer_servings                   float64
# spirit_servings                 float64
# wine_servings                   float64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
df.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0              0.0            0.0
# 1      Albania           89.0            132.0           54.0
# 2      Algeria           25.0              0.0           14.0
# 3      Andorra          245.0            138.0          312.0
# 4       Angola          217.0             57.0           45.0
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
df.dtypes
# Out:
# country                          object
# beer_servings                   float64
# spirit_servings                 float64
# wine_servings                   float64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
df.isna().sum()
# Out:
# country                         0
# beer_servings                   8
# spirit_servings                 8
# wine_servings                   6
# total_litres_of_pure_alcohol    1
# continent                       0
# dtype: int64

# %%
#use fillna function
#check the data types in info
# float - use mean or median by checking through histogram
#in histogram,if there is skewness we can use median\use mean if no skewness
#objects - use mode()[0]

# %%
frq = df.select_dtypes(include=['float'])
frq
# Out:
#      beer_servings  spirit_servings  wine_servings  \
# 0              0.0              0.0            0.0
# 1             89.0            132.0           54.0
# 2             25.0              0.0           14.0
# 3            245.0            138.0          312.0
# 4            217.0             57.0           45.0
# ..             ...              ...            ...
# 188            NaN            100.0            3.0
# 189          111.0              2.0            1.0
# 190            6.0              0.0            0.0
# 191           32.0             19.0            4.0
# 192           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol
# 0                             0.0
# 1                             4.9
# 2                             0.7
# 3                            12.4
# 4                             5.9
# ..                            ...
# 188                           7.7
# 189                           2.0
# ...

# %%
frq.hist(color='green',figsize=(25,5))
# Out:
# array([[<Axes: title={'center': 'beer_servings'}>,
#         <Axes: title={'center': 'spirit_servings'}>],
#        [<Axes: title={'center': 'wine_servings'}>,
#         <Axes: title={'center': 'total_litres_of_pure_alcohol'}>]],
#       dtype=object)

# %%
# #graphs are skewed so use median to fill na values
# Skewness is a measurement of the distortion of symmetrical distribution or asymmetry in a data set.
# Skewness is demonstrated on a bell curve when data points are not distributed symmetrically to the left and right
# sides of the median on a bell curve.

# %%
d = df['beer_servings'].fillna(df['beer_servings'].median())

# %%
d.isna().sum()
# Out:
# 0

# %%
frq.columns
# Out:
# Index(['beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol'],
#       dtype='object')

# %%
for i in ['beer_servings', 'spirit_servings', 'wine_servings','total_litres_of_pure_alcohol']:
       df[i]=df[i].fillna(df[i].median())
df[i]
# Out:
# 0       0.0
# 1       4.9
# 2       0.7
# 3      12.4
# 4       5.9
#        ...
# 188     7.7
# 189     2.0
# 190     0.1
# 191     2.5
# 192     4.7
# Name: total_litres_of_pure_alcohol, Length: 193, dtype: float64

# %%
df.isnull().sum()
# Out:
# country                         0
# beer_servings                   0
# spirit_servings                 0
# wine_servings                   0
# total_litres_of_pure_alcohol    0
# continent                       0
# dtype: int64

# %%
df.groupby('country')['spirit_servings'].mean()
# Out:
# country
# Afghanistan      0.0
# Albania        132.0
# Algeria          0.0
# Andorra        138.0
# Angola          57.0
#                ...
# Venezuela      100.0
# Vietnam          2.0
# Yemen            0.0
# Zambia          19.0
# Zimbabwe        18.0
# Name: spirit_servings, Length: 193, dtype: float64

# %%
# outlier detection and removing

# %%
plt.boxplot(df['beer_servings'])
plt.title('boxplot of beer_servings')
# Out:
# Text(0.5, 1.0, 'boxplot of beer_servings')

# %%
plt.boxplot(df['spirit_servings'])
plt.title('box plot of spirit serving')
# Out:
# Text(0.5, 1.0, 'box plot of spirit serving')

# %%
Q1=np.percentile(df['spirit_servings'],25,interpolation='midpoint')
Q2=np.percentile(df['spirit_servings'],50,interpolation='midpoint')
Q3=np.percentile(df['spirit_servings'],75,interpolation='midpoint')

print(Q1)
print(Q2)
print(Q3)
# Out:
# 5.0
# 60.0
# 128.0

# %%
df['spirit_servings'].median()
# Out:
# 60.0

# %%
IQR=Q3-Q1
IQR
# Out:
# 123.0

# %%
# THE EQUATION TO FIND THE UPPER AND LOWER LIMIT OF THE OUTLIERS
# upper_limit=Q3+1.5*IQR
# lower_limit=Q1-1.5*IQR
# print(lower_limit)
# print(upper_limit)

# %%
upper_limit=Q3+1.5*IQR
lower_limit=Q1-1.5*IQR

# %%
upper_limit
# Out:
# 312.5

# %%
lower_limit
# Out:
# -179.5

# %%
OUTLIER=[]
for x in df['spirit_servings']:
  if((x>upper_limit) or (x<lower_limit)):
    OUTLIER.append(x)
OUTLIER
# Out:
# [373.0, 438.0, 326.0, 326.0, 315.0]

# %%
df1 = df['spirit_servings']>upper_limit
df1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Name: spirit_servings, Length: 193, dtype: bool

# %%
df.loc[df1]
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 15              Belarus          142.0            373.0           42.0
# 68              Grenada          199.0            438.0           28.0
# 73                Haiti            1.0            326.0            1.0
# 141  Russian Federation          247.0            326.0           73.0
# 144           St. Lucia          171.0            315.0           71.0
#
#      total_litres_of_pure_alcohol      continent
# 15                           14.4         Europe
# 68                           11.9  North America
# 73                            5.9  North America
# 141                          11.5           Asia
# 144                          10.1  North America

# %%
df.loc[df1].index
# Out:
# Int64Index([15, 68, 73, 141, 144], dtype='int64')

# %%
df.drop([15, 68, 73, 141, 144],inplace=True)

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0              0.0            0.0
# 1      Albania           89.0            132.0           54.0
# 2      Algeria           25.0              0.0           14.0
# 3      Andorra          245.0            138.0          312.0
# 4       Angola          217.0             57.0           45.0
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
plt.boxplot(df['spirit_servings'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x78ab8952fee0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x78ab8952f880>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x78ab8952ff40>],
#  'medians': [<matplotlib.lines.Line2D at 0x78ab8952dd80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x78ab8952c310>],
#  'means': []}

# %%
plt.boxplot(df['wine_servings'])
plt.title('box plot of wine servings')
# Out:
# Text(0.5, 1.0, 'box plot of wine servings')

# %%
Q1 = np.percentile(df['wine_servings'],25,interpolation='midpoint')
Q2 = np.percentile(df['wine_servings'],50,interpolation='midpoint')
Q3 = np.percentile(df['wine_servings'],75,interpolation='midpoint')

print(Q1)
print(Q2)
print(Q3)
# Out:
# 1.0
# 9.0
# 57.5

# %%
Q3-Q1
# Out:
# 56.5

# %%
IQR=Q3-Q1
IQR
# Out:
# 56.5

# %%
upperlimit=Q3+1.5*IQR
lowerlimit=Q1-1.5*IQR

print(upperlimit)
print(lowerlimit)
# Out:
# 142.25
# -83.75

# %%
outlier=[]
for x in df['wine_servings']:
  if ((x>upperlimit) or (x<lowerlimit)):
   outlier.append(x)
outlier
# Out:
# [312.0,
#  221.0,
#  212.0,
#  191.0,
#  212.0,
#  172.0,
#  254.0,
#  278.0,
#  233.0,
#  370.0,
#  149.0,
#  175.0,
#  218.0,
#  185.0,
#  165.0,
#  237.0,
#  271.0,
#  190.0,
#  175.0,
#  339.0,
#  167.0,
#  276.0,
#  186.0,
#  280.0,
#  195.0,
#  220.0]

# %%
ws = df['wine_servings']>upperlimit
ws
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Name: wine_servings, Length: 188, dtype: bool

# %%
df.loc[ws]
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 3              Andorra          245.0            138.0          312.0
# 6            Argentina           76.0             25.0          221.0
# 8            Australia          261.0             72.0          212.0
# 9              Austria          279.0             75.0          191.0
# 16             Belgium          295.0             84.0          212.0
# 35               Chile          130.0            124.0          172.0
# 42             Croatia          230.0             87.0          254.0
# 48             Denmark          224.0             81.0          278.0
# 55   Equatorial Guinea           92.0              0.0          233.0
# 61              France          127.0            151.0          370.0
# 64             Georgia           76.0            100.0          149.0
# 65             Germany          346.0            117.0          175.0
# ...

# %%
df.loc[ws].index
# Out:
# Int64Index([  3,   6,   8,   9,  16,  35,  42,  48,  55,  61,  64,  65,  67,
#              75,  81,  83,  99, 120, 121, 136, 140, 156, 165, 166, 182, 185],
#            dtype='int64')

# %%
df.drop([  3,   6,   8,   9,  16,  35,  42,  48,  55,  61,  64,  65,  67,
         75,  81,  83,  99, 120, 121, 136, 140, 156, 165, 166, 182, 185],inplace=True)

# already run the cell once so second time they cant find the indexexx bcz its alreaddy dropped
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-90-5c1b4ad15606> in <cell line: 1>()
# ----> 1 df.drop([  3,   6,   8,   9,  16,  35,  42,  48,  55,  61,  64,  65,  67,
#       2          75,  81,  83,  99, 120, 121, 136, 140, 156, 165, 166, 182, 185],inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
# ...

# %%
df.head(10)
# Out:
#               country  beer_servings  spirit_servings  wine_servings  \
# 0         Afghanistan            0.0              0.0            0.0
# 1             Albania           89.0            132.0           54.0
# 2             Algeria           25.0              0.0           14.0
# 4              Angola          217.0             57.0           45.0
# 5   Antigua & Barbuda          102.0            128.0           45.0
# 7             Armenia           21.0            179.0           11.0
# 10         Azerbaijan           21.0             46.0            5.0
# 11            Bahamas          122.0            176.0           51.0
# 12            Bahrain           42.0             63.0            7.0
# 13         Bangladesh           76.0             60.0            9.0
#
#     total_litres_of_pure_alcohol      continent
# 0                           0.00           Asia
# 1                           4.90         Europe
# 2                           0.70         Africa
# ...

# %%
plt.boxplot(df['wine_servings'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x78ab897cad70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x78ab8f884640>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x78ab897cb070>],
#  'medians': [<matplotlib.lines.Line2D at 0x78ab8f886890>],
#  'fliers': [<matplotlib.lines.Line2D at 0x78ab8f885600>],
#  'means': []}
