# %% [markdown]
# project done by mauzum shamil

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('beer-servings.csv',index_col='Unnamed: 0')

# %%
for i in ['beer_servings', 'spirit_servings', 'wine_servings',
       'total_litres_of_pure_alcohol']:
       df[i]=df[i].fillna(df[i].median())

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0              0.0            0.0
# 1      Albania           89.0            132.0           54.0
# 2      Algeria           25.0              0.0           14.0
# 3      Andorra          245.0            138.0          312.0
# 4       Angola          217.0             57.0           45.0
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
df.shape
# Out:
# (193, 6)

# %%
df.dtypes
# Out:
# country                          object
# beer_servings                   float64
# spirit_servings                 float64
# wine_servings                   float64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %% [markdown]
# #One hot encoding

# %% [markdown]
# ####two object columns present

# %%
df1=pd.get_dummies(df)

# %%
df1.shape
# Out:
# (193, 203)

# %%
df.country.nunique()
# Out:
# 193

# %%
df.continent.nunique()
# Out:
# 6

# %% [markdown]
# ####193+6+4(numerical columns)=203

# %%
df2=df.drop('country',axis=1)#if all values in a columns is unique then it wont contribute anything to model so can drop it

# %%
df2=pd.get_dummies(df2)

# %%
df2.head()
# Out:
#    beer_servings  spirit_servings  wine_servings  \
# 0            0.0              0.0            0.0
# 1           89.0            132.0           54.0
# 2           25.0              0.0           14.0
# 3          245.0            138.0          312.0
# 4          217.0             57.0           45.0
#
#    total_litres_of_pure_alcohol  continent_Africa  continent_Asia  \
# 0                           0.0                 0               1
# 1                           4.9                 0               0
# 2                           0.7                 1               0
# 3                          12.4                 0               0
# 4                           5.9                 1               0
#
#    continent_Europe  continent_North America  continent_Oceania  \
# 0                 0                        0                  0
# 1                 1                        0                  0
# 2                 0                        0                  0
# ...

# %% [markdown]
# #Label encoding

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0              0.0            0.0
# 1      Albania           89.0            132.0           54.0
# 2      Algeria           25.0              0.0           14.0
# 3      Andorra          245.0            138.0          312.0
# 4       Angola          217.0             57.0           45.0
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['continent']=le.fit_transform(df['continent'])

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0              0.0            0.0
# 1      Albania           89.0            132.0           54.0
# 2      Algeria           25.0              0.0           14.0
# 3      Andorra          245.0            138.0          312.0
# 4       Angola          217.0             57.0           45.0
#
#    total_litres_of_pure_alcohol  continent
# 0                           0.0          1
# 1                           4.9          2
# 2                           0.7          0
# 3                          12.4          2
# 4                           5.9          0

# %%
X=df.drop('total_litres_of_pure_alcohol',axis=1)
Y=df['total_litres_of_pure_alcohol']
Z=df['continent']

# %%
#machine learning model does not take categorical values so encoding required

# %% [markdown]
# #Min Max scaling

# %%
#scaling only done for features ie values used for predicting,scaling not done on target columns

# %%
X.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  continent
# 0  Afghanistan            0.0              0.0            0.0          1
# 1      Albania           89.0            132.0           54.0          2
# 2      Algeria           25.0              0.0           14.0          0
# 3      Andorra          245.0            138.0          312.0          2
# 4       Angola          217.0             57.0           45.0          0

# %%
#removing country columns
X=X.drop('country',axis=1)

# %%
X.head()
# Out:
#    beer_servings  spirit_servings  wine_servings  continent
# 0            0.0              0.0            0.0          1
# 1           89.0            132.0           54.0          2
# 2           25.0              0.0           14.0          0
# 3          245.0            138.0          312.0          2
# 4          217.0             57.0           45.0          0

# %%
#scaling is not done on encoded columns,so removing continent columns

# %%
X=X.drop('continent',axis=1)

# %%
X.head()
# Out:
#    beer_servings  spirit_servings  wine_servings
# 0            0.0              0.0            0.0
# 1           89.0            132.0           54.0
# 2           25.0              0.0           14.0
# 3          245.0            138.0          312.0
# 4          217.0             57.0           45.0

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax= MinMaxScaler(feature_range=(0,1))

# %%
X1=minmax.fit_transform(X)

# %%
X1

# %%
type(X1)#now x1 become an array
# Out:
# numpy.ndarray

# %%
df.columns

# %%
X1=pd.DataFrame(X1,columns=['beer_servings', 'spirit_servings', 'wine_servings'])#converting x1 back into data frame

# %%
X1

# %%
X1.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings
# count     193.000000       193.000000     193.000000
# mean        0.276375         0.187806       0.132124
# std         0.262181         0.199519       0.214641
# min         0.000000         0.000000       0.000000
# 25%         0.055851         0.011416       0.002703
# 50%         0.202128         0.136986       0.024324
# 75%         0.454787         0.292237       0.159459
# max         1.000000         1.000000       1.000000

# %%
X2=pd.concat([X1,Z,Y],axis=1)

# %%
X2
# Out:
#      beer_servings  spirit_servings  wine_servings  continent  \
# 0         0.000000         0.000000       0.000000          1
# 1         0.236702         0.301370       0.145946          2
# 2         0.066489         0.000000       0.037838          0
# 3         0.651596         0.315068       0.843243          2
# 4         0.577128         0.130137       0.121622          0
# ..             ...              ...            ...        ...
# 188       0.202128         0.228311       0.008108          5
# 189       0.295213         0.004566       0.002703          1
# 190       0.015957         0.000000       0.000000          1
# 191       0.085106         0.043379       0.010811          0
# 192       0.170213         0.041096       0.010811          0
#
#      total_litres_of_pure_alcohol
# 0                             0.0
# 1                             4.9
# 2                             0.7
# 3                            12.4
# 4                             5.9
# ...

# %% [markdown]
# #standard scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
stdsclr= StandardScaler()#creating the instance

# %%
X3=stdsclr.fit_transform(X)#X3 is an array

# %%
X3=pd.DataFrame(X2,columns=['beer_servings', 'spirit_servings', 'wine_servings'])#converting x2 back into data frame

# %%
X3
# Out:
#      beer_servings  spirit_servings  wine_servings
# 0         0.000000         0.000000       0.000000
# 1         0.236702         0.301370       0.145946
# 2         0.066489         0.000000       0.037838
# 3         0.651596         0.315068       0.843243
# 4         0.577128         0.130137       0.121622
# ..             ...              ...            ...
# 188       0.202128         0.228311       0.008108
# 189       0.295213         0.004566       0.002703
# 190       0.015957         0.000000       0.000000
# 191       0.085106         0.043379       0.010811
# 192       0.170213         0.041096       0.010811
#
# [193 rows x 3 columns]

# %%
X4=pd.concat([X3,Z,Y],axis=1)

# %%
X4
# Out:
#      beer_servings  spirit_servings  wine_servings  continent  \
# 0         0.000000         0.000000       0.000000          1
# 1         0.236702         0.301370       0.145946          2
# 2         0.066489         0.000000       0.037838          0
# 3         0.651596         0.315068       0.843243          2
# 4         0.577128         0.130137       0.121622          0
# ..             ...              ...            ...        ...
# 188       0.202128         0.228311       0.008108          5
# 189       0.295213         0.004566       0.002703          1
# 190       0.015957         0.000000       0.000000          1
# 191       0.085106         0.043379       0.010811          0
# 192       0.170213         0.041096       0.010811          0
#
#      total_litres_of_pure_alcohol
# 0                             0.0
# 1                             4.9
# 2                             0.7
# 3                            12.4
# 4                             5.9
# ...
